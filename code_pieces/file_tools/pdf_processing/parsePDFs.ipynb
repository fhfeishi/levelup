# %%
from markitdown import MarkItDown
import os 
from pathlib import Path

# %%
md = MarkItDown(docintel_endpoint="<document_intelligence_endpoint>")
result = md.convert(r"D:\ddesktop\agentdemos\codespace\pdfs\消防人员个人防护用可穿戴设备.pdf")
print(result.text_content)
md_path = os.path.splitext(r"D:\ddesktop\agentdemos\codespace\pdfs\消防人员个人防护用可穿戴设备.pdf")[0] + ".md"   # 与原文件同名
with open(md_path, "w", encoding="utf-8") as f:
    f.write(result.text_content)

print(f"已保存 Markdown：{md_path}")
# Out:
# (19)国家知识产权局(12)发明专利申请(10)申请公布号 (43)申请公布日 (21)申请号 202510455591.X(22)申请日 2025.04.11(71)申请人 合肥耀安科技有限公司地址 230000 安徽省合肥市高新区望江西路800号创新产业园一期C3-101/103/104/105/106(72)发明人 王毅　陶亮亮　赵翔　周文洪　王攀　(74)专利代理机构 北京正企知航知识产权代理有限公司 16333专利代理师 王君昌(51)Int.Cl.A42B 3/04(2006.01)A42B 3/12(2006.01)A42B 3/20(2006.01)A42B 3/30(2006.01) (54)发明名称消防人员个人防护用可穿戴设备(57)摘要本发明涉及消防设备技术领域，且公开了消防人员个人防护用可穿戴设备，包括盔体，所述盔体的一侧固定连接有面罩，盔体的底部固定安装有固定带，所述盔体的一侧固定安装有蓄电池，面罩的外侧壁固定连接有吹气管，吹气管的表面均开设有多个吹气孔，面罩与盔体连接处固定连接有吸尘块，吸尘块表面均开设有多个吸尘孔，盔体的内部均安装有清理机构，盔体表面转动连接有可以转动的齿环，齿环的表面固定安装有与齿环同步转动的摄像头，齿环的一端安装有带动齿环转动的传动机构，该设备通过风力对面罩表面进行清理，不会阻挡消防人员的视线，同时对摄像头进行角度调节，保证外部的消防人员也能够看清火场内的情况。权利要求书1页  说明书5页  附图8页CN 120078209 A2025.06.03CN 120078209 A1.消防人员个人防护用可穿戴设备，包括盔体(1)，所述盔体(1)的一侧固定连接有对面部进行保护的面罩(2)，盔体(1)的底部固定安装有可以适应消防员头部大小的固定带(3)，其特征在于，所述盔体(1)的一侧固定安装有带动该装置内所有电器元件工作的蓄电池(4)，面罩(2)的外侧壁固定连接有对面罩(2)表面灰尘进行清理的吹气管(5)，吹气管(5)的表面均开设有对面罩(2)表面灰尘清理的多个吹气孔(6)，面罩(2)与盔体(1)连接处固定连接有对灰尘进行吸附的吸尘块(7)，吸尘块(7)表面均开设有便于对灰尘进行吸附的多个吸尘孔(8)，盔体(1)的内部均安装有带动吹气管(5)与吸尘块(7)进行工作的清理机构。2.根据权利要求1所述的消防人员个人防护用可穿戴设备，其特征在于：所述盔体(1)表面转动连接有可以转动的齿环(9)，齿环(9)的表面固定安装有与齿环(9)同步转动的摄像头(10)，齿环(9)的一端安装有带动齿环(9)转动的传动机构，所述盔体(1)的内壁固定连接有对消防员头部进行缓冲的多个弹簧(11)，多个弹簧(11)的一端固定连接有弧形板(12)，弧形板(12)的表面固定连接有对消防员头部进行保护的橡胶软垫(13)。3.根据权利要求1所述的消防人员个人防护用可穿戴设备，其特征在于：所述清理机构包括固定连接在盔体(1)两侧的微型风机(15)，微型风机(15)与吹气管(5)一端通过气管连接，盔体(1)顶部固定连接有对烟尘进行抽取的微型抽气机(16)，微型抽气机(16)与吸尘块(7)一端通过气管连接。4.根据权利要求3所述的消防人员个人防护用可穿戴设备，其特征在于：所述盔体(1)顶部与微型抽气机(16)连接的表面滑动连接有对灰尘收集的收集盒(18)，收集盒(18)的表面开设有对灰尘进行过滤的多个过滤孔(19)。5.根据权利要求3所述的消防人员个人防护用可穿戴设备，其特征在于：所述清理机构还包括固定连接在微型风机(15)和微型抽气机(16)一侧的烟雾过滤器(17)。6.根据权利要求2所述的消防人员个人防护用可穿戴设备，其特征在于：所述传动机构包括固定连接在盔体(1)一侧的微型电机(20)，微型电机(20)的输出轴固定连接有齿轮(21)，齿轮(21)啮合齿环(9)表面用于带动齿环(9)进行转动。7.根据权利要求2所述的消防人员个人防护用可穿戴设备，其特征在于：所述摄像头(10)的上方固定连接有对摄像头(10)清晰度进行辅助的照明灯(22)。8.根据权利要求7所述的消防人员个人防护用可穿戴设备，其特征在于：所述照明灯(22)和摄像头(10)与盔体(1)接触的两侧均固定连接有便于对摄像头(10)进行持续供电的无线电圈(23)。9.根据权利要求8所述的消防人员个人防护用可穿戴设备，其特征在于：所述盔体(1)内部固定连接有对消防员头部进行应急保护的气囊(24)，气囊(24)的输气端固定连接有对气囊(24)进行充气的气体发生器(25)，弧形板(12)的表面固定连接有对气体发生器(25)进行开关的压力感应器(26)。10.根据权利要求9所述的消防人员个人防护用可穿戴设备，其特征在于：所述气囊(24)位于橡胶软垫(13)下方及盔体(1)内侧壁。权　利　要　求　书1/1页2CN 120078209 A2消防人员个人防护用可穿戴设备技术领域[0001]本发明涉及消防设备技术领域，具体为消防人员个人防护用可穿戴设备。背景技术[0002]消防人员个人防护用设备是保障消防员在灭火救援等危险作业中生命安全的重要装备，这些设备的设计和制造需符合严格的安全标准，以确保其可靠性和有效性。[0003]消防人员个人防护用设备包括：基础防护装备、辅助功能装备、特殊环境强化装备和其他关键装备，其中基础防护装备包括消防头盔、灭火防护服和消防手套与防护靴。[0004]在基础防护装备其中，现有的消防头盔采用硬质材料制成，配备防护面罩，保护头部免受坠落物冲击、高温辐射及侧向挤压。[0005]现有技术中的消防头盔，由盔体、面罩和固定带组成，在发生火灾时，将消防人员将消防头盔戴在头上，保护消防人员的头部，同时可以防止外部杂物飘入消防人员的眼中。[0006]现有技术通过盔体、面罩和固定带对消防人员进行保护，但是仍存在以下不足：[0007]1.现有技术中当消防人员戴着头盔在火场进行救援时，由于火场的烟雾较大，同时空气中飘浮的灰尘和焚烧的杂物较多，导致灰尘会附着在面罩表面，现有的清理方式一般为毛刷对面罩表面的灰尘进行擦拭，但是在毛刷擦拭面罩表面时，毛刷会阻挡消防人员的视线，同时毛刷处于外部也会沾染灰尘，在对面罩清理时，面罩表面的灰尘会越来越多，严重影响消防人员救援行动。[0008]2.现有技术中消防头盔表面的摄像头为固定结构，与火场外部的消防人员进行无线连接，使外部的消防人员也能够看清火场内的情况，从而对火场内的消防人员进行指挥，在摄像头拍摄时，只能根据消防人员头部对应的位置进行拍摄，非常限制拍摄视角，实用性低。[0009]因此我们提出消防人员个人防护用可穿戴设备来解决上述背景中的问题。发明内容[0010]本发明的目的在于提供消防人员个人防护用可穿戴设备，以解决上述背景技术中提出的不方便对面罩表面的灰尘进行清理，以及摄像头拍摄视角的限制的问题。[0011]为了解决上述技术问题，本发明提供如下技术方案：[0012]消防人员个人防护用可穿戴设备，包括盔体，所述盔体的一侧固定连接有对面部进行保护的面罩，盔体的底部固定安装有可以适应消防员头部大小的固定带，所述盔体的一侧固定安装有带动该装置内所有电器元件工作的蓄电池，面罩的外侧壁固定连接有对面罩表面灰尘进行清理的吹气管，吹气管的表面均开设有对面罩表面灰尘清理的多个吹气孔，面罩与盔体连接处固定连接有对灰尘进行吸附的吸尘块，吸尘块表面均开设有便于对灰尘进行吸附的多个吸尘孔，盔体的内部均安装有带动吹气管与吸尘块进行工作的清理机构，盔体表面转动连接有可以转动的齿环，齿环的表面固定安装有与齿环同步转动的摄像头，齿环的一端安装有带动齿环转动的传动机构。说　明　书1/5页3CN 120078209 A3[0013]所述盔体的内壁固定连接有对消防员头部进行缓冲的多个弹簧，多个弹簧的一端固定连接有弧形板，弧形板的表面固定连接有对消防员头部进行保护的橡胶软垫。[0014]所述清理机构包括固定连接在盔体两侧的微型风机，微型风机与吹气管一端通过气管连接，盔体顶部固定连接有对烟尘进行抽取的微型抽气机，微型抽气机与吸尘块一端通过气管连接。[0015]所述盔体顶部与微型抽气机连接的表面滑动连接有对灰尘收集的收集盒，收集盒的表面开设有对灰尘进行过滤的多个过滤孔。[0016]所述清理机构还包括固定连接在微型风机和微型抽气机一侧的烟雾过滤器。[0017]所述传动机构包括固定连接在盔体一侧的微型电机，微型电机的输出轴固定连接有齿轮，齿轮啮合齿环表面用于带动齿环进行转动。[0018]所述摄像头的上方固定连接有对摄像头清晰度进行辅助的照明灯。[0019]所述照明灯和摄像头与盔体接触的两侧均固定连接有便于对摄像头进行持续供电的无线电圈。[0020]所述盔体内部固定连接有对消防员头部进行应急保护的气囊，气囊的输气端固定连接有对气囊进行充气的气体发生器，弧形板的表面固定连接有对气体发生器进行开关的压力感应器。[0021]所述气囊位于橡胶软垫下方及盔体内侧壁。[0022]与现有技术相比，本发明所达到的有益效果是：[0023]本发明通过将盔体套在消防员头部，通过固定带将盔体固定连接在消防员头部，面罩对消防员面部进行保护，在消防员进入火场时，启动微型风机，使微型风机送风到达吹气管内，使吹气管带动多个吹气孔对面罩表面进行吹气，将面罩表面的灰尘进行吹散，通过微型抽气机抽气，使吸尘块内部产生负压，使吸尘块带动多个吸尘孔对吹散的灰尘进行吸附，通过风力对面罩表面进行清理，不会阻挡消防人员的视线，同时不会影响消防员的行动，通过微型风机和微型抽气机一侧的烟雾过滤器，对烟雾进行过滤，防止将烟雾吸附到面罩表面。[0024]通过微型 ...
# 已保存 Markdown：D:\ddesktop\agentdemos\codespace\pdfs\消防人员个人防护用可穿戴设备.md
