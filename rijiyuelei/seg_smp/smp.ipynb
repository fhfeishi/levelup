# %%
import segmentation_models_pytorch as smp

model = smp.Unet()
model.save_pretrained(r"E:\codespace\collections\weights\smp_unet")

restored_model = smp.from_pretrained(r"E:\codespace\collections\weights\smp_unet")

# 说是为了兼容Hugging-face， 了解一下吧
# config.json      : 保存模型的配置参数，如编码器名称、层数、激活函数等。
#                     这使得在加载模型时，能够根据配置自动构建相应的模型架构。
# model.safetensors: 使用 safetensors 格式保存模型权重，
#                     这是一种高效且安全的二进制格式，
#                     避免了传统 .pth 或 .pt 文件可能存在的安全风险（如代码注入）。
# README.md:  一些说明，训练数据集呀、指标等。
# Out:
# Loading weights from local directory

# %%
print(restored_model)
# Out:
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# .pth  .pt
import torch, os 
weight_dir = r"E:\codespace\collections\weights\smp_unet"

torch.save(model.state_dict(), os.path.join(weight_dir, 'smp_unet.pth'))
model.load_state_dict(torch.load(os.path.join(weight_dir, 'smp_unet.pth'), map_location='cpu'))
# Out:
# <All keys matched successfully>

# %%
# check for encoders
# from segmentation_models_pytorch.encoders import get_encoder_names
# print(get_encoder_names())
